# %%
import seaborn as sns

sns.set_style("darkgrid")

# %%
import numpy as np
import pandas as pd
df_in = pd.read_csv('data-de-synpuf/DE1_0_2008_to_2010_Inpatient_Claims_Sample_1.csv')
df_in
# Out:
#             DESYNPUF_ID           CLM_ID  SEGMENT  CLM_FROM_DT  CLM_THRU_DT  \
# 0      00013D2EFD8E45D1  196661176988405        1   20100312.0   20100313.0
# 1      00016F745862898F  196201177000368        1   20090412.0   20090418.0
# 2      00016F745862898F  196661177015632        1   20090831.0   20090902.0
# 3      00016F745862898F  196091176981058        1   20090917.0   20090920.0
# 4      00016F745862898F  196261176983265        1   20100626.0   20100701.0
# ...                 ...              ...      ...          ...          ...
# 66768  FFF8B49458F9FFA7  196641177004609        1   20080329.0   20080331.0
# 66769  FFF8B49458F9FFA7  196851176989979        1   20081012.0   20081013.0
# 66770  FFFA950301FCA748  196341176990073        1   20100109.0   20100112.0
# 66771  FFFC880E13CA6278  196191176959044        1   20081012.0   20081020.0
# 66772  FFFE3ED9582AD46E  196711176994055        1   20090417.0   20090418.0
#
#       PRVDR_NUM  CLM_PMT_AMT  NCH_PRMRY_PYR_CLM_PD_AMT  AT_PHYSN_NPI  \
# 0        2600GD       4000.0                       0.0  3.139084e+09
# 1        3900MB      26000.0                       0.0  6.476809e+09
# 2        3900HM       5000.0                       0.0  6.119985e+08
# 3        3913XU       5000.0                       0.0  4.971603e+09
# 4        3900MB      16000.0                       0.0  6.408400e+09
# ...         ...          ...                       ...           ...
# 66768    0100UV       3000.0                       0.0  2.509032e+09
# 66769    0100UV      10000.0                       0.0  3.401706e+08
# 66770    0300QJ       7000.0                       0.0  9.059627e+09
# 66771    36T2DK      10000.0                       0.0  9.809003e+08
# 66772    0600RM       2000.0                       0.0  5.351953e+09
#
#        OP_PHYSN_NPI  ...  HCPCS_CD_36  HCPCS_CD_37 HCPCS_CD_38  HCPCS_CD_39  \
# 0               NaN  ...          NaN          NaN         NaN          NaN
# 1               NaN  ...          NaN          NaN         NaN          NaN
# 2      6.119985e+08  ...          NaN          NaN         NaN          NaN
# 3               NaN  ...          NaN          NaN         NaN          NaN
# 4      1.960860e+09  ...          NaN          NaN         NaN          NaN
# ...             ...  ...          ...          ...         ...          ...
# 66768           NaN  ...          NaN          NaN         NaN          NaN
# 66769  6.624958e+08  ...          NaN          NaN         NaN          NaN
# 66770           NaN  ...          NaN          NaN         NaN          NaN
# 66771  9.809003e+08  ...          NaN          NaN         NaN          NaN
# 66772           NaN  ...          NaN          NaN         NaN          NaN
#
#        HCPCS_CD_40  HCPCS_CD_41  HCPCS_CD_42  HCPCS_CD_43  HCPCS_CD_44  \
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 66768          NaN          NaN          NaN          NaN          NaN
# 66769          NaN          NaN          NaN          NaN          NaN
# 66770          NaN          NaN          NaN          NaN          NaN
# 66771          NaN          NaN          NaN          NaN          NaN
# 66772          NaN          NaN          NaN          NaN          NaN
#
#       HCPCS_CD_45
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 66768         NaN
# 66769         NaN
# 66770         NaN
# 66771         NaN
# 66772         NaN
#
# [66773 rows x 81 columns]

# %%
df_out = pd.read_csv('data-de-synpuf/DE1_0_2008_to_2010_Outpatient_Claims_Sample_1.csv')
df_out
# Out:
# /home/vscode/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (21,23,24,25,26,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              DESYNPUF_ID           CLM_ID  SEGMENT  CLM_FROM_DT  CLM_THRU_DT  \
# 0       00013D2EFD8E45D1  542192281063886        1   20080904.0   20080904.0
# 1       00016F745862898F  542272281166593        1   20090602.0   20090602.0
# 2       00016F745862898F  542282281644416        1   20090623.0   20090623.0
# 3       0001FDD721E223DC  542642281250669        1   20091011.0   20091011.0
# 4       00024B3D2352D2D0  542242281386963        1   20080712.0   20080712.0
# ...                  ...              ...      ...          ...          ...
# 790785  FFFF7C107A4E385A  542672281474119        1   20091117.0   20091118.0
# 790786  FFFF7C107A4E385A  542802281199642        1   20100122.0   20100122.0
# 790787  FFFF7C107A4E385A  542972281048297        1   20100127.0   20100127.0
# 790788  FFFF7C107A4E385A  542552281122714        1   20100130.0   20100130.0
# 790789  FFFF7C107A4E385A  542542281466911        1   20100220.0   20100220.0
#
#        PRVDR_NUM  CLM_PMT_AMT  NCH_PRMRY_PYR_CLM_PD_AMT  AT_PHYSN_NPI  \
# 0         2600RA         50.0                       0.0  4.824842e+09
# 1         3901GS         30.0                       0.0  2.963420e+09
# 2         3939PG         30.0                       0.0  5.737808e+09
# 3         3902NU         30.0                       0.0  1.233848e+09
# 4         5200TV         30.0                       0.0  9.688809e+09
# ...          ...          ...                       ...           ...
# 790785    2100MP         80.0                       0.0  8.791289e+09
# 790786    21006R         10.0                       0.0  1.756767e+09
# 790787    2100UA         70.0                       0.0  5.296829e+09
# 790788    2100SU         40.0                       0.0  5.604771e+09
# 790789    21008S        400.0                       0.0  3.953045e+09
#
#         OP_PHYSN_NPI  ...  HCPCS_CD_36  HCPCS_CD_37 HCPCS_CD_38 HCPCS_CD_39  \
# 0                NaN  ...          NaN          NaN         NaN         NaN
# 1                NaN  ...          NaN          NaN         NaN         NaN
# 2                NaN  ...          NaN          NaN         NaN         NaN
# 3                NaN  ...          NaN          NaN         NaN         NaN
# 4                NaN  ...          NaN          NaN         NaN         NaN
# ...              ...  ...          ...          ...         ...         ...
# 790785           NaN  ...          NaN          NaN         NaN         NaN
# 790786           NaN  ...          NaN          NaN         NaN         NaN
# 790787           NaN  ...          NaN          NaN         NaN         NaN
# 790788  5.604771e+09  ...          NaN          NaN         NaN         NaN
# 790789           NaN  ...          NaN          NaN         NaN         NaN
#
#        HCPCS_CD_40 HCPCS_CD_41 HCPCS_CD_42 HCPCS_CD_43 HCPCS_CD_44 HCPCS_CD_45
# 0              NaN         NaN         NaN         NaN         NaN         NaN
# 1              NaN         NaN         NaN         NaN         NaN         NaN
# 2              NaN         NaN         NaN         NaN         NaN         NaN
# 3              NaN         NaN         NaN         NaN         NaN         NaN
# 4              NaN         NaN         NaN         NaN         NaN         NaN
# ...            ...         ...         ...         ...         ...         ...
# 790785         NaN         NaN         NaN         NaN         NaN         NaN
# 790786         NaN         NaN         NaN         NaN         NaN         NaN
# 790787         NaN         NaN         NaN         NaN         NaN         NaN
# 790788         NaN         NaN         NaN         NaN         NaN         NaN
# 790789         NaN         NaN         NaN         NaN         NaN         NaN
#
# [790790 rows x 76 columns]

# %%
df_claims = df_in[['CLM_PMT_AMT','CLM_FROM_DT']].groupby('CLM_FROM_DT').sum().join(
    df_out[['CLM_PMT_AMT','CLM_FROM_DT']].groupby('CLM_FROM_DT').sum(),
    rsuffix='_out',
    how='inner',    
).rename(columns={
    'CLM_PMT_AMT': 'total_inpatient',
    'CLM_PMT_AMT_out': 'total_outpatient',
})         

for sub in ['inpatient', 'outpatient']:
   df_claims[f'log_total_{sub}'] = np.log(df_claims[f'total_{sub}'])
df_claims = df_claims[[col for col in df_claims.columns if col.startswith('log')]]

df_claims
# Out:
#              log_total_inpatient  log_total_outpatient
# CLM_FROM_DT
# 20071212.0             10.950807              8.829080
# 20071213.0             11.643954              8.250620
# 20071214.0              8.987197              9.258178
# 20071215.0              9.998798              8.389360
# 20071217.0             10.691945              9.630366
# ...                          ...                   ...
# 20101226.0             11.472103             10.879555
# 20101227.0             10.545341             10.863604
# 20101228.0             10.571317             10.537150
# 20101229.0             10.373491             10.716416
# 20101230.0              9.952278             10.742681
#
# [1113 rows x 2 columns]

# %%
# center everything
df_claims = (df_claims - df_claims.mean()) / df_claims.std()

# %%
sns.pairplot(data=df_claims)

# %%
sns.displot(data=df_claims, x='log_total_inpatient', y='log_total_outpatient')

# %%
import flowtorch.bijectors
import flowtorch.parameters
import flowtorch.distributions as fdist

import torch
import torch.distributions as dist
import torch.optim

from tqdm.auto import tqdm

d = 2

def fit_pq(flow, opt, num_epochs, retain_graph=False, loss_every=100, **kwargs):
    losses = []
    for it in tqdm(range(num_epochs)):
        opt.zero_grad()
        nll = None
        while not nll:
            try:
                nll = -flow.log_prob(torch.tensor(df_claims.to_numpy()).float()).mean()
            except ValueError:
                continue
        if it % loss_every == 0:
            tqdm.write(f"neg log lik: {nll}")
            losses.append(nll.item()) 
        nll.backward(retain_graph=retain_graph)
        opt.step()
    return losses

    
def train_advi(lr=5e-3, num_epochs=1_000, **kwargs):
    advi_flow = fdist.Flow(
    dist.Independent(dist.Normal(torch.zeros(d), torch.ones(d)), 1),
        flowtorch.bijectors.AffineAutoregressive(
            params=flowtorch.parameters.DenseAutoregressive(hidden_dims=(64,64))
        )
    )
    advi_params = advi_flow.parameters()
    return fit_pq(advi_flow, torch.optim.Adam(advi_flow.parameters(), lr=lr), num_epochs=num_epochs, **kwargs), advi_flow, None

# %%
import torch.nn as nn


def train_taf(lr=5e-3, nu_init=4, num_epochs=1_000, **kwargs):
    taf_nu = nn.Parameter(torch.ones(1)*nu_init, requires_grad=True)
    taf_flow = fdist.Flow(
        dist.Independent(dist.StudentT(df=taf_nu.exp() * torch.ones(d)), 1),
        flowtorch.bijectors.AffineAutoregressive(
            params=flowtorch.parameters.DenseAutoregressive(hidden_dims=(64,64)),
        )
    )
    taf_params = list(taf_flow.parameters()) + [taf_nu]
    taf_opt = torch.optim.Adam(taf_params, lr=lr)
    return fit_pq(taf_flow, taf_opt, num_epochs, retain_graph=True, **kwargs), taf_flow, taf_nu

# %%
import torch.nn as nn

def train_ataf(lr=5e-3, nu_init=4, num_epochs=1_000, **kwargs):
    ftvi_nu = nn.Parameter(torch.ones(d)*nu_init, requires_grad=True)

    ftvi_flow = fdist.Flow(
        dist.Independent(dist.StudentT(df=ftvi_nu.exp()), 1),
        flowtorch.bijectors.AffineAutoregressive(
            params=flowtorch.parameters.DenseAutoregressive(hidden_dims=(64,64)),
        )
    )
    params = list(ftvi_flow.parameters()) + [ftvi_nu]
    opt = torch.optim.Adam(params, lr=lr)

    return fit_pq(ftvi_flow, opt, num_epochs, retain_graph=True, **kwargs), ftvi_flow, ftvi_nu

# %%
all_losses = []
all_samples = []

num_trials = 10

loss_every = 100
for trial in tqdm(range(num_trials)):
    losses = {}
    samples = {}
    for (name, train_fn) in [
        ('advi', train_advi),
        ('taf', train_taf),
        ('ataf', train_ataf),
    ]:
        tqdm.write(f"method: {name}")
        loss, flow, nu = train_fn(lr=2e-3, nu_init=torch.log(torch.tensor(4.)), num_epochs=5_000, loss_every=loss_every)
        losses[name] = loss
        samples[name] = flow.sample((1_000,))
        if name != 'advi':
            tqdm.write(f"nu: {nu}")
    all_losses.append(losses)
    all_samples.append(samples)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# method: advi
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.788468599319458
# neg log lik: 1.9752702713012695
# neg log lik: 1.9684463739395142
# neg log lik: 1.9664663076400757
# neg log lik: 1.964663028717041
# neg log lik: 1.962082028388977
# neg log lik: 1.958412766456604
# neg log lik: 1.9531019926071167
# neg log lik: 1.9475178718566895
# neg log lik: 1.942500352859497
# neg log lik: 1.9349011182785034
# neg log lik: 1.9278273582458496
# neg log lik: 1.9239706993103027
# neg log lik: 1.921254277229309
# neg log lik: 1.9194936752319336
# neg log lik: 1.9182403087615967
# neg log lik: 1.9169342517852783
# neg log lik: 1.9154717922210693
# neg log lik: 1.9142099618911743
# neg log lik: 1.913666844367981
# neg log lik: 1.9112545251846313
# neg log lik: 1.9100230932235718
# neg log lik: 1.908022165298462
# neg log lik: 1.906590461730957
# neg log lik: 1.90499746799469
# neg log lik: 1.9028228521347046
# neg log lik: 1.9018330574035645
# neg log lik: 1.9002537727355957
# neg log lik: 1.898944616317749
# neg log lik: 1.8996384143829346
# neg log lik: 1.8975155353546143
# neg log lik: 1.8972244262695312
# neg log lik: 1.8966622352600098
# neg log lik: 1.8959039449691772
# neg log lik: 1.8950022459030151
# neg log lik: 1.8944950103759766
# neg log lik: 1.8941155672073364
# neg log lik: 1.8935993909835815
# neg log lik: 1.8930755853652954
# neg log lik: 1.8929126262664795
# neg log lik: 1.8918577432632446
# neg log lik: 1.8914028406143188
# neg log lik: 1.8907936811447144
# neg log lik: 1.8906077146530151
# neg log lik: 1.89116370677948
# neg log lik: 1.889618992805481
# neg log lik: 1.8890748023986816
# neg log lik: 1.8894442319869995
# neg log lik: 1.8881313800811768
# neg log lik: 1.8886418342590332
# method: taf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.623563766479492
# neg log lik: 1.7694432735443115
# neg log lik: 1.7260971069335938
# neg log lik: 1.7115775346755981
# neg log lik: 1.7062171697616577
# neg log lik: 1.7038929462432861
# neg log lik: 1.702355146408081
# neg log lik: 1.7010183334350586
# neg log lik: 1.7000316381454468
# neg log lik: 1.6987208127975464
# neg log lik: 1.6973849534988403
# neg log lik: 1.695711374282837
# neg log lik: 1.6938737630844116
# neg log lik: 1.6922801733016968
# neg log lik: 1.6907005310058594
# neg log lik: 1.689581036567688
# neg log lik: 1.6882480382919312
# neg log lik: 1.6872341632843018
# neg log lik: 1.6863243579864502
# neg log lik: 1.6857680082321167
# neg log lik: 1.6857516765594482
# neg log lik: 1.6839911937713623
# neg log lik: 1.6836398839950562
# neg log lik: 1.6838481426239014
# neg log lik: 1.682212233543396
# neg log lik: 1.6816288232803345
# neg log lik: 1.6811507940292358
# neg log lik: 1.6811928749084473
# neg log lik: 1.6803267002105713
# neg log lik: 1.6808197498321533
# neg log lik: 1.6796561479568481
# neg log lik: 1.6788675785064697
# neg log lik: 1.6793330907821655
# neg log lik: 1.6790602207183838
# neg log lik: 1.6786879301071167
# neg log lik: 1.677708387374878
# neg log lik: 1.6777812242507935
# neg log lik: 1.6770752668380737
# neg log lik: 1.6768913269042969
# neg log lik: 1.6767079830169678
# neg log lik: 1.6767526865005493
# neg log lik: 1.6762592792510986
# neg log lik: 1.6756558418273926
# neg log lik: 1.6758298873901367
# neg log lik: 1.6752135753631592
# neg log lik: 1.6748836040496826
# neg log lik: 1.6743464469909668
# neg log lik: 1.6743035316467285
# neg log lik: 1.6739659309387207
# neg log lik: 1.6742420196533203
# nu: Parameter containing:
# tensor([-7.5112], requires_grad=True)
# method: ataf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.8931005001068115
# neg log lik: 1.750420331954956
# neg log lik: 1.691342830657959
# neg log lik: 1.6613545417785645
# neg log lik: 1.6474652290344238
# neg log lik: 1.6412577629089355
# neg log lik: 1.638533353805542
# neg log lik: 1.6366106271743774
# neg log lik: 1.6345608234405518
# neg log lik: 1.6322431564331055
# neg log lik: 1.6296573877334595
# neg log lik: 1.627665638923645
# neg log lik: 1.626136302947998
# neg log lik: 1.6242339611053467
# neg log lik: 1.6232095956802368
# neg log lik: 1.6216102838516235
# neg log lik: 1.6204063892364502
# neg log lik: 1.6196027994155884
# neg log lik: 1.6180977821350098
# neg log lik: 1.619131088256836
# neg log lik: 1.6164746284484863
# neg log lik: 1.615384578704834
# neg log lik: 1.616094946861267
# neg log lik: 1.6139811277389526
# neg log lik: 1.6147844791412354
# neg log lik: 1.6131702661514282
# neg log lik: 1.613781213760376
# neg log lik: 1.6115663051605225
# neg log lik: 1.6115148067474365
# neg log lik: 1.6105602979660034
# neg log lik: 1.6101739406585693
# neg log lik: 1.6117677688598633
# neg log lik: 1.6100965738296509
# neg log lik: 1.6089438199996948
# neg log lik: 1.6090810298919678
# neg log lik: 1.6098008155822754
# neg log lik: 1.608540415763855
# neg log lik: 1.6079998016357422
# neg log lik: 1.6081472635269165
# neg log lik: 1.6077654361724854
# neg log lik: 1.6071478128433228
# neg log lik: 1.6068981885910034
# neg log lik: 1.6064790487289429
# neg log lik: 1.606519103050232
# neg log lik: 1.6071112155914307
# neg log lik: 1.6061840057373047
# neg log lik: 1.6053708791732788
# neg log lik: 1.605858564376831
# neg log lik: 1.6053663492202759
# neg log lik: 1.6047663688659668
# nu: Parameter containing:
# tensor([-9.0766, -7.6353], requires_grad=True)
# method: advi
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 3.0259506702423096
# neg log lik: 1.977179765701294
# neg log lik: 1.9699840545654297
# neg log lik: 1.9670021533966064
# neg log lik: 1.9648064374923706
# neg log lik: 1.9625765085220337
# neg log lik: 1.9600332975387573
# neg log lik: 1.9568097591400146
# neg log lik: 1.9519176483154297
# neg log lik: 1.9467687606811523
# neg log lik: 1.9412928819656372
# neg log lik: 1.9348951578140259
# neg log lik: 1.9294540882110596
# neg log lik: 1.9250174760818481
# neg log lik: 1.9213956594467163
# neg log lik: 1.9185283184051514
# neg log lik: 1.9156850576400757
# neg log lik: 1.9137825965881348
# neg log lik: 1.911997675895691
# neg log lik: 1.909946084022522
# neg log lik: 1.9088728427886963
# neg log lik: 1.90730619430542
# neg log lik: 1.9054368734359741
# neg log lik: 1.904346227645874
# neg log lik: 1.904784917831421
# neg log lik: 1.9030169248580933
# neg log lik: 1.9030665159225464
# neg log lik: 1.9016387462615967
# neg log lik: 1.90107262134552
# neg log lik: 1.900794506072998
# neg log lik: 1.900508165359497
# neg log lik: 1.9001280069351196
# neg log lik: 1.8999582529067993
# neg log lik: 1.8985260725021362
# neg log lik: 1.8983324766159058
# neg log lik: 1.8982826471328735
# neg log lik: 1.8966293334960938
# neg log lik: 1.8974679708480835
# neg log lik: 1.8953843116760254
# neg log lik: 1.8950787782669067
# neg log lik: 1.8950644731521606
# neg log lik: 1.8952516317367554
# neg log lik: 1.8935805559158325
# neg log lik: 1.8940719366073608
# neg log lik: 1.8930600881576538
# neg log lik: 1.8924046754837036
# neg log lik: 1.8944733142852783
# neg log lik: 1.8928797245025635
# neg log lik: 1.89251708984375
# neg log lik: 1.8907986879348755
# method: taf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.729403257369995
# neg log lik: 1.7771155834197998
# neg log lik: 1.7069392204284668
# neg log lik: 1.6672768592834473
# neg log lik: 1.6474992036819458
# neg log lik: 1.6386382579803467
# neg log lik: 1.6345489025115967
# neg log lik: 1.6320918798446655
# neg log lik: 1.6306331157684326
# neg log lik: 1.6286886930465698
# neg log lik: 1.6268802881240845
# neg log lik: 1.6262961626052856
# neg log lik: 1.6244862079620361
# neg log lik: 1.6224485635757446
# neg log lik: 1.6227461099624634
# neg log lik: 1.6208385229110718
# neg log lik: 1.620224952697754
# neg log lik: 1.6192169189453125
# neg log lik: 1.6184046268463135
# neg log lik: 1.616235613822937
# neg log lik: 1.6167458295822144
# neg log lik: 1.615002989768982
# neg log lik: 1.6131278276443481
# neg log lik: 1.6164636611938477
# neg log lik: 1.6139034032821655
# neg log lik: 1.616104006767273
# neg log lik: 1.6142845153808594
# neg log lik: 1.6133112907409668
# neg log lik: 1.61186683177948
# neg log lik: 1.6115626096725464
# neg log lik: 1.6146527528762817
# neg log lik: 1.609480619430542
# neg log lik: 1.610209584236145
# neg log lik: 1.607995629310608
# neg log lik: 1.613139271736145
# neg log lik: 1.6108019351959229
# neg log lik: 1.6068949699401855
# neg log lik: 1.6089907884597778
# neg log lik: 1.6093318462371826
# neg log lik: 1.6087201833724976
# neg log lik: 1.6084455251693726
# neg log lik: 1.6061009168624878
# neg log lik: 1.6057353019714355
# neg log lik: 1.6062651872634888
# neg log lik: 1.606696605682373
# neg log lik: 1.6071686744689941
# neg log lik: 1.6091231107711792
# neg log lik: 1.606087327003479
# neg log lik: 1.6093173027038574
# neg log lik: 1.6065192222595215
# nu: Parameter containing:
# tensor([-9.2286], requires_grad=True)
# method: ataf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.5142316818237305
# neg log lik: 1.713756799697876
# neg log lik: 1.6656267642974854
# neg log lik: 1.6454132795333862
# neg log lik: 1.63762629032135
# neg log lik: 1.6340672969818115
# neg log lik: 1.6321014165878296
# neg log lik: 1.6307467222213745
# neg log lik: 1.6294094324111938
# neg log lik: 1.628886103630066
# neg log lik: 1.6276333332061768
# neg log lik: 1.6256684064865112
# neg log lik: 1.624528169631958
# neg log lik: 1.6236042976379395
# neg log lik: 1.6221044063568115
# neg log lik: 1.621181845664978
# neg log lik: 1.6203445196151733
# neg log lik: 1.6190489530563354
# neg log lik: 1.618238091468811
# neg log lik: 1.6193827390670776
# neg log lik: 1.6169778108596802
# neg log lik: 1.6167343854904175
# neg log lik: 1.6150333881378174
# neg log lik: 1.623551368713379
# neg log lik: 1.6147559881210327
# neg log lik: 1.6137019395828247
# neg log lik: 1.6144905090332031
# neg log lik: 1.6117327213287354
# neg log lik: 1.611798882484436
# neg log lik: 1.6119436025619507
# neg log lik: 1.6120667457580566
# neg log lik: 1.6099340915679932
# neg log lik: 1.609161138534546
# neg log lik: 1.6084917783737183
# neg log lik: 1.6076310873031616
# neg log lik: 1.6069064140319824
# neg log lik: 1.6066522598266602
# neg log lik: 1.60543954372406
# neg log lik: 1.6055450439453125
# neg log lik: 1.6046366691589355
# neg log lik: 1.6043713092803955
# neg log lik: 1.6041879653930664
# neg log lik: 1.6035901308059692
# neg log lik: 1.6032435894012451
# neg log lik: 1.6026368141174316
# neg log lik: 1.6029106378555298
# neg log lik: 1.6021379232406616
# neg log lik: 1.6024537086486816
# neg log lik: 1.6014907360076904
# neg log lik: 1.601386308670044
# nu: Parameter containing:
# tensor([-9.2048, -7.7914], requires_grad=True)
# method: advi
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 3.3164312839508057
# neg log lik: 1.9768455028533936
# neg log lik: 1.971595048904419
# neg log lik: 1.968668818473816
# neg log lik: 1.965394377708435
# neg log lik: 1.962402582168579
# neg log lik: 1.9600789546966553
# neg log lik: 1.9575759172439575
# neg log lik: 1.9551169872283936
# neg log lik: 1.9520304203033447
# neg log lik: 1.9482169151306152
# neg log lik: 1.9360936880111694
# neg log lik: 1.925620198249817
# neg log lik: 1.9189236164093018
# neg log lik: 1.9158107042312622
# neg log lik: 1.9144330024719238
# neg log lik: 1.912612795829773
# neg log lik: 1.9116219282150269
# neg log lik: 1.911713719367981
# neg log lik: 1.9103113412857056
# neg log lik: 1.9099658727645874
# neg log lik: 1.9094668626785278
# neg log lik: 1.9094167947769165
# neg log lik: 1.9090566635131836
# neg log lik: 1.9087170362472534
# neg log lik: 1.909214735031128
# neg log lik: 1.9082809686660767
# neg log lik: 1.9084110260009766
# neg log lik: 1.907957673072815
# neg log lik: 1.9074205160140991
# neg log lik: 1.9072656631469727
# neg log lik: 1.9076370000839233
# neg log lik: 1.9071050882339478
# neg log lik: 1.9067795276641846
# neg log lik: 1.9070664644241333
# neg log lik: 1.906294584274292
# neg log lik: 1.9060050249099731
# neg log lik: 1.9058319330215454
# neg log lik: 1.9062844514846802
# neg log lik: 1.9055204391479492
# neg log lik: 1.9052484035491943
# neg log lik: 1.9052398204803467
# neg log lik: 1.9051846265792847
# neg log lik: 1.9048430919647217
# neg log lik: 1.9042420387268066
# neg log lik: 1.904198169708252
# neg log lik: 1.9041661024093628
# neg log lik: 1.9037002325057983
# neg log lik: 1.9034477472305298
# neg log lik: 1.9029388427734375
# method: taf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.6738853454589844
# neg log lik: 1.770706295967102
# neg log lik: 1.7273755073547363
# neg log lik: 1.712899088859558
# neg log lik: 1.7080589532852173
# neg log lik: 1.7050533294677734
# neg log lik: 1.7029187679290771
# neg log lik: 1.701106309890747
# neg log lik: 1.6996253728866577
# neg log lik: 1.6984397172927856
# neg log lik: 1.6974650621414185
# neg log lik: 1.6965065002441406
# neg log lik: 1.6955509185791016
# neg log lik: 1.6947790384292603
# neg log lik: 1.6940408945083618
# neg log lik: 1.6936126947402954
# neg log lik: 1.6928253173828125
# neg log lik: 1.6922413110733032
# neg log lik: 1.6911617517471313
# neg log lik: 1.690409779548645
# neg log lik: 1.6897660493850708
# neg log lik: 1.6891082525253296
# neg log lik: 1.6887205839157104
# neg log lik: 1.6875438690185547
# neg log lik: 1.68682062625885
# neg log lik: 1.6868534088134766
# neg log lik: 1.6858261823654175
# neg log lik: 1.6855422258377075
# neg log lik: 1.6847018003463745
# neg log lik: 1.6853456497192383
# neg log lik: 1.6835788488388062
# neg log lik: 1.6854350566864014
# neg log lik: 1.6829984188079834
# neg log lik: 1.6825584173202515
# neg log lik: 1.681979775428772
# neg log lik: 1.6817985773086548
# neg log lik: 1.6822384595870972
# neg log lik: 1.683073878288269
# neg log lik: 1.6812385320663452
# neg log lik: 1.6801551580429077
# neg log lik: 1.682565450668335
# neg log lik: 1.680863618850708
# neg log lik: 1.6814192533493042
# neg log lik: 1.6814117431640625
# neg log lik: 1.679682731628418
# neg log lik: 1.6793485879898071
# neg log lik: 1.6838523149490356
# neg log lik: 1.6787601709365845
# neg log lik: 1.6783580780029297
# neg log lik: 1.6811940670013428
# nu: Parameter containing:
# tensor([-7.5090], requires_grad=True)
# method: ataf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.736774206161499
# neg log lik: 1.7264795303344727
# neg log lik: 1.6698023080825806
# neg log lik: 1.6485371589660645
# neg log lik: 1.6408476829528809
# neg log lik: 1.6373008489608765
# neg log lik: 1.633285641670227
# neg log lik: 1.63126540184021
# neg log lik: 1.6297866106033325
# neg log lik: 1.6287175416946411
# neg log lik: 1.6272644996643066
# neg log lik: 1.6260032653808594
# neg log lik: 1.625024676322937
# neg log lik: 1.6242294311523438
# neg log lik: 1.6230982542037964
# neg log lik: 1.6222349405288696
# neg log lik: 1.621851921081543
# neg log lik: 1.6203519105911255
# neg log lik: 1.6192926168441772
# neg log lik: 1.618192195892334
# neg log lik: 1.6173442602157593
# neg log lik: 1.6162596940994263
# neg log lik: 1.61528480052948
# neg log lik: 1.6145379543304443
# neg log lik: 1.6133830547332764
# neg log lik: 1.6125116348266602
# neg log lik: 1.611430287361145
# neg log lik: 1.610204815864563
# neg log lik: 1.608962893486023
# neg log lik: 1.6085479259490967
# neg log lik: 1.607573390007019
# neg log lik: 1.6058194637298584
# neg log lik: 1.6064354181289673
# neg log lik: 1.6042197942733765
# neg log lik: 1.604266881942749
# neg log lik: 1.6033785343170166
# neg log lik: 1.6055450439453125
# neg log lik: 1.6033953428268433
# neg log lik: 1.6035581827163696
# neg log lik: 1.602720856666565
# neg log lik: 1.6017359495162964
# neg log lik: 1.6013762950897217
# neg log lik: 1.6039199829101562
# neg log lik: 1.6006543636322021
# neg log lik: 1.6013505458831787
# neg log lik: 1.5991944074630737
# neg log lik: 1.5987629890441895
# neg log lik: 1.5982508659362793
# neg log lik: 1.601414442062378
# neg log lik: 1.5972509384155273
# nu: Parameter containing:
# tensor([-9.0434, -7.7726], requires_grad=True)
# method: advi
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.8498642444610596
# neg log lik: 1.9063419103622437
# neg log lik: 1.9016940593719482
# neg log lik: 1.898605465888977
# neg log lik: 1.8959156274795532
# neg log lik: 1.8949401378631592
# neg log lik: 1.8944035768508911
# neg log lik: 1.8939021825790405
# neg log lik: 1.8934144973754883
# neg log lik: 1.8930120468139648
# neg log lik: 1.8924798965454102
# neg log lik: 1.8920705318450928
# neg log lik: 1.8917694091796875
# neg log lik: 1.8911597728729248
# neg log lik: 1.8907381296157837
# neg log lik: 1.890365719795227
# neg log lik: 1.8899226188659668
# neg log lik: 1.889631748199463
# neg log lik: 1.889028787612915
# neg log lik: 1.888641357421875
# neg log lik: 1.8879613876342773
# neg log lik: 1.887793779373169
# neg log lik: 1.886900782585144
# neg log lik: 1.8868318796157837
# neg log lik: 1.886169672012329
# neg log lik: 1.8854905366897583
# neg log lik: 1.885076642036438
# neg log lik: 1.8847901821136475
# neg log lik: 1.8845309019088745
# neg log lik: 1.8841211795806885
# neg log lik: 1.8834391832351685
# neg log lik: 1.8832454681396484
# neg log lik: 1.8829697370529175
# neg log lik: 1.8829636573791504
# neg log lik: 1.8832871913909912
# neg log lik: 1.8819267749786377
# neg log lik: 1.8814939260482788
# neg log lik: 1.8813667297363281
# neg log lik: 1.8815066814422607
# neg log lik: 1.880692720413208
# neg log lik: 1.8805912733078003
# neg log lik: 1.8806442022323608
# neg log lik: 1.8801535367965698
# neg log lik: 1.8795804977416992
# neg log lik: 1.8793585300445557
# neg log lik: 1.8797650337219238
# neg log lik: 1.8789106607437134
# neg log lik: 1.8788198232650757
# neg log lik: 1.878366231918335
# neg log lik: 1.8783503770828247
# method: taf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.7365610599517822
# neg log lik: 1.7600736618041992
# neg log lik: 1.7223575115203857
# neg log lik: 1.7116544246673584
# neg log lik: 1.7086750268936157
# neg log lik: 1.7070544958114624
# neg log lik: 1.705368995666504
# neg log lik: 1.7037358283996582
# neg log lik: 1.7026742696762085
# neg log lik: 1.701500415802002
# neg log lik: 1.7010571956634521
# neg log lik: 1.7003839015960693
# neg log lik: 1.6997867822647095
# neg log lik: 1.6994469165802002
# neg log lik: 1.6988461017608643
# neg log lik: 1.6983333826065063
# neg log lik: 1.6980667114257812
# neg log lik: 1.6977781057357788
# neg log lik: 1.697184443473816
# neg log lik: 1.696582317352295
# neg log lik: 1.6959413290023804
# neg log lik: 1.6953262090682983
# neg log lik: 1.6944361925125122
# neg log lik: 1.69386887550354
# neg log lik: 1.6929947137832642
# neg log lik: 1.6937346458435059
# neg log lik: 1.6913923025131226
# neg log lik: 1.6910371780395508
# neg log lik: 1.6902122497558594
# neg log lik: 1.6899625062942505
# neg log lik: 1.6903562545776367
# neg log lik: 1.6883411407470703
# neg log lik: 1.6880372762680054
# neg log lik: 1.687947392463684
# neg log lik: 1.68759286403656
# neg log lik: 1.6874864101409912
# neg log lik: 1.6862239837646484
# neg log lik: 1.6867738962173462
# neg log lik: 1.685892939567566
# neg log lik: 1.684841275215149
# neg log lik: 1.6853400468826294
# neg log lik: 1.6846258640289307
# neg log lik: 1.6830188035964966
# neg log lik: 1.6835143566131592
# neg log lik: 1.6816070079803467
# neg log lik: 1.6808704137802124
# neg log lik: 1.6804713010787964
# neg log lik: 1.682625651359558
# neg log lik: 1.6797096729278564
# neg log lik: 1.679154634475708
# nu: Parameter containing:
# tensor([-7.7010], requires_grad=True)
# method: ataf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.720222234725952
# neg log lik: 1.72206449508667
# neg log lik: 1.6729238033294678
# neg log lik: 1.6507856845855713
# neg log lik: 1.642403483390808
# neg log lik: 1.639419674873352
# neg log lik: 1.6379567384719849
# neg log lik: 1.6353697776794434
# neg log lik: 1.633175253868103
# neg log lik: 1.6315494775772095
# neg log lik: 1.6306467056274414
# neg log lik: 1.629056453704834
# neg log lik: 1.6280937194824219
# neg log lik: 1.6270909309387207
# neg log lik: 1.6256144046783447
# neg log lik: 1.6244410276412964
# neg log lik: 1.6231756210327148
# neg log lik: 1.6221188306808472
# neg log lik: 1.6208105087280273
# neg log lik: 1.6208865642547607
# neg log lik: 1.6185812950134277
# neg log lik: 1.617936134338379
# neg log lik: 1.6182068586349487
# neg log lik: 1.616248369216919
# neg log lik: 1.6148099899291992
# neg log lik: 1.6142022609710693
# neg log lik: 1.6135233640670776
# neg log lik: 1.6126147508621216
# neg log lik: 1.6122279167175293
# neg log lik: 1.612038493156433
# neg log lik: 1.6123892068862915
# neg log lik: 1.6098012924194336
# neg log lik: 1.609143853187561
# neg log lik: 1.6095967292785645
# neg log lik: 1.6080652475357056
# neg log lik: 1.6078037023544312
# neg log lik: 1.6068615913391113
# neg log lik: 1.6073487997055054
# neg log lik: 1.6073856353759766
# neg log lik: 1.6054667234420776
# neg log lik: 1.606304407119751
# neg log lik: 1.6073161363601685
# neg log lik: 1.6041450500488281
# neg log lik: 1.6041545867919922
# neg log lik: 1.6043070554733276
# neg log lik: 1.605498194694519
# neg log lik: 1.6037293672561646
# neg log lik: 1.6025176048278809
# neg log lik: 1.6022365093231201
# neg log lik: 1.6025285720825195
# nu: Parameter containing:
# tensor([-9.1494, -7.8671], requires_grad=True)
# method: advi
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.929464817047119
# neg log lik: 1.9743589162826538
# neg log lik: 1.969970941543579
# neg log lik: 1.9671329259872437
# neg log lik: 1.9651076793670654
# neg log lik: 1.9635449647903442
# neg log lik: 1.9617153406143188
# neg log lik: 1.9599543809890747
# neg log lik: 1.957875370979309
# neg log lik: 1.9557225704193115
# neg log lik: 1.9529955387115479
# neg log lik: 1.9506984949111938
# neg log lik: 1.9485158920288086
# neg log lik: 1.9460848569869995
# neg log lik: 1.9418971538543701
# neg log lik: 1.9387279748916626
# neg log lik: 1.9348431825637817
# neg log lik: 1.9317781925201416
# neg log lik: 1.930301308631897
# neg log lik: 1.9268525838851929
# neg log lik: 1.9249248504638672
# neg log lik: 1.9226875305175781
# neg log lik: 1.9226614236831665
# neg log lik: 1.9197505712509155
# neg log lik: 1.9187419414520264
# neg log lik: 1.920638084411621
# neg log lik: 1.9185742139816284
# neg log lik: 1.9177496433258057
# neg log lik: 1.919318675994873
# neg log lik: 1.9203741550445557
# neg log lik: 1.9184807538986206
# neg log lik: 1.9174631834030151
# neg log lik: 1.9096708297729492
# neg log lik: 1.9072827100753784
# neg log lik: 1.9049968719482422
# neg log lik: 1.903012752532959
# neg log lik: 1.9012460708618164
# neg log lik: 1.9006178379058838
# neg log lik: 1.8981293439865112
# neg log lik: 1.8978551626205444
# neg log lik: 1.895426869392395
# neg log lik: 1.8944456577301025
# neg log lik: 1.8934855461120605
# neg log lik: 1.8934565782546997
# neg log lik: 1.8926222324371338
# neg log lik: 1.8929826021194458
# neg log lik: 1.890864372253418
# neg log lik: 1.8903589248657227
# neg log lik: 1.8909167051315308
# neg log lik: 1.8898727893829346
# method: taf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.796058416366577
# neg log lik: 1.8044497966766357
# neg log lik: 1.745286226272583
# neg log lik: 1.7205263376235962
# neg log lik: 1.7110341787338257
# neg log lik: 1.7071847915649414
# neg log lik: 1.7053090333938599
# neg log lik: 1.7040072679519653
# neg log lik: 1.7029916048049927
# neg log lik: 1.7021459341049194
# neg log lik: 1.7014058828353882
# neg log lik: 1.7009968757629395
# neg log lik: 1.7001218795776367
# neg log lik: 1.6992207765579224
# neg log lik: 1.6987509727478027
# neg log lik: 1.69802725315094
# neg log lik: 1.6971014738082886
# neg log lik: 1.6960140466690063
# neg log lik: 1.6954371929168701
# neg log lik: 1.6943811178207397
# neg log lik: 1.693997859954834
# neg log lik: 1.6942311525344849
# neg log lik: 1.69304358959198
# neg log lik: 1.692903995513916
# neg log lik: 1.692353367805481
# neg log lik: 1.691778540611267
# neg log lik: 1.6912091970443726
# neg log lik: 1.6908302307128906
# neg log lik: 1.6909633874893188
# neg log lik: 1.6902629137039185
# neg log lik: 1.6899348497390747
# neg log lik: 1.689682126045227
# neg log lik: 1.6895114183425903
# neg log lik: 1.6884363889694214
# neg log lik: 1.6884685754776
# neg log lik: 1.6878602504730225
# neg log lik: 1.6881920099258423
# neg log lik: 1.6872152090072632
# neg log lik: 1.6877943277359009
# neg log lik: 1.6873332262039185
# neg log lik: 1.6875437498092651
# neg log lik: 1.6861664056777954
# neg log lik: 1.689134955406189
# neg log lik: 1.6855823993682861
# neg log lik: 1.6859711408615112
# neg log lik: 1.6871957778930664
# neg log lik: 1.6849597692489624
# neg log lik: 1.6858619451522827
# neg log lik: 1.6846956014633179
# neg log lik: 1.6849656105041504
# nu: Parameter containing:
# tensor([-7.1547], requires_grad=True)
# method: ataf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.6992087364196777
# neg log lik: 1.7022888660430908
# neg log lik: 1.6619716882705688
# neg log lik: 1.6448707580566406
# neg log lik: 1.6383695602416992
# neg log lik: 1.6356202363967896
# neg log lik: 1.6341183185577393
# neg log lik: 1.6327487230300903
# neg log lik: 1.6314505338668823
# neg log lik: 1.6298692226409912
# neg log lik: 1.6281399726867676
# neg log lik: 1.6259263753890991
# neg log lik: 1.624751091003418
# neg log lik: 1.6220049858093262
# neg log lik: 1.6211981773376465
# neg log lik: 1.6211215257644653
# neg log lik: 1.6190584897994995
# neg log lik: 1.6180466413497925
# neg log lik: 1.6177006959915161
# neg log lik: 1.6170052289962769
# neg log lik: 1.6156269311904907
# neg log lik: 1.61525297164917
# neg log lik: 1.6143202781677246
# neg log lik: 1.6136062145233154
# neg log lik: 1.6133625507354736
# neg log lik: 1.6126917600631714
# neg log lik: 1.6122835874557495
# neg log lik: 1.611302137374878
# neg log lik: 1.610762357711792
# neg log lik: 1.6097056865692139
# neg log lik: 1.6092637777328491
# neg log lik: 1.608764410018921
# neg log lik: 1.6082147359848022
# neg log lik: 1.6082899570465088
# neg log lik: 1.6078344583511353
# neg log lik: 1.606998085975647
# neg log lik: 1.6064718961715698
# neg log lik: 1.6062906980514526
# neg log lik: 1.6058580875396729
# neg log lik: 1.604896903038025
# neg log lik: 1.6050496101379395
# neg log lik: 1.604708194732666
# neg log lik: 1.6047017574310303
# neg log lik: 1.603959083557129
# neg log lik: 1.6036157608032227
# neg log lik: 1.6035339832305908
# neg log lik: 1.602686882019043
# neg log lik: 1.602560043334961
# neg log lik: 1.6029772758483887
# neg log lik: 1.6021602153778076
# nu: Parameter containing:
# tensor([-9.2413, -7.9183], requires_grad=True)
# method: advi
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.9896252155303955
# neg log lik: 1.9054162502288818
# neg log lik: 1.898110270500183
# neg log lik: 1.8954437971115112
# neg log lik: 1.894661545753479
# neg log lik: 1.894127607345581
# neg log lik: 1.8936744928359985
# neg log lik: 1.8931223154067993
# neg log lik: 1.8926817178726196
# neg log lik: 1.8921619653701782
# neg log lik: 1.8916172981262207
# neg log lik: 1.891048550605774
# neg log lik: 1.8904775381088257
# neg log lik: 1.8898839950561523
# neg log lik: 1.8892546892166138
# neg log lik: 1.8886141777038574
# neg log lik: 1.8879530429840088
# neg log lik: 1.8872790336608887
# neg log lik: 1.886443018913269
# neg log lik: 1.8856620788574219
# neg log lik: 1.884864091873169
# neg log lik: 1.8841334581375122
# neg log lik: 1.8835337162017822
# neg log lik: 1.8826605081558228
# neg log lik: 1.881855845451355
# neg log lik: 1.8810638189315796
# neg log lik: 1.8803489208221436
# neg log lik: 1.8793838024139404
# neg log lik: 1.8787020444869995
# neg log lik: 1.877720832824707
# neg log lik: 1.8768763542175293
# neg log lik: 1.8757883310317993
# neg log lik: 1.8751109838485718
# neg log lik: 1.8744136095046997
# neg log lik: 1.873482346534729
# neg log lik: 1.872591495513916
# neg log lik: 1.8722681999206543
# neg log lik: 1.8717875480651855
# neg log lik: 1.871891975402832
# neg log lik: 1.8699111938476562
# neg log lik: 1.8700568675994873
# neg log lik: 1.8691006898880005
# neg log lik: 1.86813223361969
# neg log lik: 1.8669898509979248
# neg log lik: 1.8667712211608887
# neg log lik: 1.8666518926620483
# neg log lik: 1.8659613132476807
# neg log lik: 1.8648698329925537
# neg log lik: 1.864746332168579
# neg log lik: 1.8634744882583618
# method: taf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.6750316619873047
# neg log lik: 1.8113887310028076
# neg log lik: 1.7483781576156616
# neg log lik: 1.7225326299667358
# neg log lik: 1.712273120880127
# neg log lik: 1.7083475589752197
# neg log lik: 1.706580638885498
# neg log lik: 1.7054810523986816
# neg log lik: 1.7045130729675293
# neg log lik: 1.7036304473876953
# neg log lik: 1.7027579545974731
# neg log lik: 1.7016397714614868
# neg log lik: 1.7004469633102417
# neg log lik: 1.6993043422698975
# neg log lik: 1.6978070735931396
# neg log lik: 1.6962506771087646
# neg log lik: 1.696333408355713
# neg log lik: 1.6940217018127441
# neg log lik: 1.6936497688293457
# neg log lik: 1.693068504333496
# neg log lik: 1.691953420639038
# neg log lik: 1.6913646459579468
# neg log lik: 1.690745234489441
# neg log lik: 1.6901931762695312
# neg log lik: 1.6896871328353882
# neg log lik: 1.6891348361968994
# neg log lik: 1.688717246055603
# neg log lik: 1.6880987882614136
# neg log lik: 1.687267541885376
# neg log lik: 1.6865273714065552
# neg log lik: 1.6861944198608398
# neg log lik: 1.689082145690918
# neg log lik: 1.6842707395553589
# neg log lik: 1.683799386024475
# neg log lik: 1.685030221939087
# neg log lik: 1.684184193611145
# neg log lik: 1.68194580078125
# neg log lik: 1.6816648244857788
# neg log lik: 1.6822624206542969
# neg log lik: 1.681160569190979
# neg log lik: 1.6812326908111572
# neg log lik: 1.6804882287979126
# neg log lik: 1.6802101135253906
# neg log lik: 1.678804874420166
# neg log lik: 1.6801815032958984
# neg log lik: 1.6781108379364014
# neg log lik: 1.6803947687149048
# neg log lik: 1.6834161281585693
# neg log lik: 1.6794432401657104
# neg log lik: 1.6766629219055176
# nu: Parameter containing:
# tensor([-6.9955], requires_grad=True)
# method: ataf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.859529733657837
# neg log lik: 1.767339825630188
# neg log lik: 1.6982520818710327
# neg log lik: 1.6630491018295288
# neg log lik: 1.6461435556411743
# neg log lik: 1.639003038406372
# neg log lik: 1.635466456413269
# neg log lik: 1.633194923400879
# neg log lik: 1.6312426328659058
# neg log lik: 1.6296377182006836
# neg log lik: 1.62865149974823
# neg log lik: 1.6271400451660156
# neg log lik: 1.6269667148590088
# neg log lik: 1.6255027055740356
# neg log lik: 1.6243342161178589
# neg log lik: 1.6240653991699219
# neg log lik: 1.6236069202423096
# neg log lik: 1.6229884624481201
# neg log lik: 1.6233394145965576
# neg log lik: 1.6225581169128418
# neg log lik: 1.6242456436157227
# neg log lik: 1.6207964420318604
# neg log lik: 1.6365946531295776
# neg log lik: 1.6215101480484009
# neg log lik: 1.620376706123352
# neg log lik: 1.620056390762329
# neg log lik: 1.6191320419311523
# neg log lik: 1.6191381216049194
# neg log lik: 1.6183807849884033
# neg log lik: 1.61821448802948
# neg log lik: 1.6179534196853638
# neg log lik: 1.617371678352356
# neg log lik: 1.6170415878295898
# neg log lik: 1.6166855096817017
# neg log lik: 1.618701696395874
# neg log lik: 1.616024136543274
# neg log lik: 1.6168146133422852
# neg log lik: 1.6163967847824097
# neg log lik: 1.6161022186279297
# neg log lik: 1.615132212638855
# neg log lik: 1.6150438785552979
# neg log lik: 1.6154637336730957
# neg log lik: 1.6151454448699951
# neg log lik: 1.614609718322754
# neg log lik: 1.6142604351043701
# neg log lik: 1.6138756275177002
# neg log lik: 1.6136163473129272
# neg log lik: 1.613147497177124
# neg log lik: 1.6128454208374023
# neg log lik: 1.6123969554901123
# nu: Parameter containing:
# tensor([-8.9329, -8.1090], requires_grad=True)
# method: advi
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.6989619731903076
# neg log lik: 1.9059944152832031
# neg log lik: 1.896531581878662
# neg log lik: 1.8942583799362183
# neg log lik: 1.8935779333114624
# neg log lik: 1.8929507732391357
# neg log lik: 1.8923146724700928
# neg log lik: 1.8914978504180908
# neg log lik: 1.890869379043579
# neg log lik: 1.8903297185897827
# neg log lik: 1.889936923980713
# neg log lik: 1.8893935680389404
# neg log lik: 1.8887951374053955
# neg log lik: 1.8883036375045776
# neg log lik: 1.8877044916152954
# neg log lik: 1.8871647119522095
# neg log lik: 1.886600136756897
# neg log lik: 1.8859792947769165
# neg log lik: 1.8854317665100098
# neg log lik: 1.8852969408035278
# neg log lik: 1.8844988346099854
# neg log lik: 1.8838660717010498
# neg log lik: 1.8833560943603516
# neg log lik: 1.8840066194534302
# neg log lik: 1.8824578523635864
# neg log lik: 1.881932258605957
# neg log lik: 1.8815349340438843
# neg log lik: 1.8814319372177124
# neg log lik: 1.881489634513855
# neg log lik: 1.88042414188385
# neg log lik: 1.8815516233444214
# neg log lik: 1.879913330078125
# neg log lik: 1.879703402519226
# neg log lik: 1.8788939714431763
# neg log lik: 1.8784657716751099
# neg log lik: 1.8781521320343018
# neg log lik: 1.8779566287994385
# neg log lik: 1.8774975538253784
# neg log lik: 1.8771077394485474
# neg log lik: 1.877143144607544
# neg log lik: 1.8773584365844727
# neg log lik: 1.876332402229309
# neg log lik: 1.8760261535644531
# neg log lik: 1.8758100271224976
# neg log lik: 1.8757247924804688
# neg log lik: 1.8753156661987305
# neg log lik: 1.8751569986343384
# neg log lik: 1.8750582933425903
# neg log lik: 1.8745406866073608
# neg log lik: 1.8746522665023804
# method: taf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.7862679958343506
# neg log lik: 1.8148365020751953
# neg log lik: 1.755648136138916
# neg log lik: 1.7250782251358032
# neg log lik: 1.7133147716522217
# neg log lik: 1.709052324295044
# neg log lik: 1.707134485244751
# neg log lik: 1.7053699493408203
# neg log lik: 1.7041492462158203
# neg log lik: 1.7031874656677246
# neg log lik: 1.7023961544036865
# neg log lik: 1.7019593715667725
# neg log lik: 1.701265573501587
# neg log lik: 1.7008986473083496
# neg log lik: 1.700478434562683
# neg log lik: 1.7001445293426514
# neg log lik: 1.7000027894973755
# neg log lik: 1.699589729309082
# neg log lik: 1.699380874633789
# neg log lik: 1.6992934942245483
# neg log lik: 1.6989765167236328
# neg log lik: 1.6986900568008423
# neg log lik: 1.6983991861343384
# neg log lik: 1.6980645656585693
# neg log lik: 1.6976585388183594
# neg log lik: 1.697588324546814
# neg log lik: 1.6973638534545898
# neg log lik: 1.6958657503128052
# neg log lik: 1.6952505111694336
# neg log lik: 1.694440484046936
# neg log lik: 1.6934994459152222
# neg log lik: 1.69282066822052
# neg log lik: 1.694402813911438
# neg log lik: 1.6951072216033936
# neg log lik: 1.6899372339248657
# neg log lik: 1.690040111541748
# neg log lik: 1.6884360313415527
# neg log lik: 1.692543864250183
# neg log lik: 1.6869661808013916
# neg log lik: 1.6873044967651367
# neg log lik: 1.6861281394958496
# neg log lik: 1.6862854957580566
# neg log lik: 1.6864618062973022
# neg log lik: 1.6848186254501343
# neg log lik: 1.6845649480819702
# neg log lik: 1.6858915090560913
# neg log lik: 1.685351014137268
# neg log lik: 1.6837764978408813
# neg log lik: 1.6842008829116821
# neg log lik: 1.6843980550765991
# nu: Parameter containing:
# tensor([-7.0393], requires_grad=True)
# method: ataf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.722200632095337
# neg log lik: 1.7393972873687744
# neg log lik: 1.6811434030532837
# neg log lik: 1.6530410051345825
# neg log lik: 1.6407461166381836
# neg log lik: 1.635665774345398
# neg log lik: 1.6333364248275757
# neg log lik: 1.6316606998443604
# neg log lik: 1.6299915313720703
# neg log lik: 1.6285886764526367
# neg log lik: 1.626407504081726
# neg log lik: 1.625027060508728
# neg log lik: 1.6238518953323364
# neg log lik: 1.6235591173171997
# neg log lik: 1.6208819150924683
# neg log lik: 1.6212173700332642
# neg log lik: 1.6283081769943237
# neg log lik: 1.6188924312591553
# neg log lik: 1.6186412572860718
# neg log lik: 1.6165915727615356
# neg log lik: 1.6185747385025024
# neg log lik: 1.6166824102401733
# neg log lik: 1.6144683361053467
# neg log lik: 1.6136318445205688
# neg log lik: 1.6129741668701172
# neg log lik: 1.6146447658538818
# neg log lik: 1.612504243850708
# neg log lik: 1.611751675605774
# neg log lik: 1.61082124710083
# neg log lik: 1.6102116107940674
# neg log lik: 1.609391212463379
# neg log lik: 1.6082878112792969
# neg log lik: 1.607503056526184
# neg log lik: 1.607470989227295
# neg log lik: 1.6069260835647583
# neg log lik: 1.6063848733901978
# neg log lik: 1.6057473421096802
# neg log lik: 1.6053118705749512
# neg log lik: 1.6052992343902588
# neg log lik: 1.6042450666427612
# neg log lik: 1.6041167974472046
# neg log lik: 1.6041297912597656
# neg log lik: 1.603681206703186
# neg log lik: 1.6035196781158447
# neg log lik: 1.6033586263656616
# neg log lik: 1.6026089191436768
# neg log lik: 1.602087378501892
# neg log lik: 1.6030914783477783
# neg log lik: 1.6025476455688477
# neg log lik: 1.6019502878189087
# nu: Parameter containing:
# tensor([-9.0955, -7.8208], requires_grad=True)
# method: advi
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.813593864440918
# neg log lik: 1.9789457321166992
# neg log lik: 1.9697272777557373
# neg log lik: 1.965298056602478
# neg log lik: 1.96147620677948
# neg log lik: 1.9573124647140503
# neg log lik: 1.952428936958313
# neg log lik: 1.9473395347595215
# neg log lik: 1.9419136047363281
# neg log lik: 1.9341048002243042
# neg log lik: 1.926383137702942
# neg log lik: 1.9199730157852173
# neg log lik: 1.9149041175842285
# neg log lik: 1.9114471673965454
# neg log lik: 1.9092981815338135
# neg log lik: 1.9072699546813965
# neg log lik: 1.9057869911193848
# neg log lik: 1.9049220085144043
# neg log lik: 1.9036625623703003
# neg log lik: 1.9031895399093628
# neg log lik: 1.902230143547058
# neg log lik: 1.9018124341964722
# neg log lik: 1.900391936302185
# neg log lik: 1.899916648864746
# neg log lik: 1.8991594314575195
# neg log lik: 1.8982152938842773
# neg log lik: 1.8977630138397217
# neg log lik: 1.8972773551940918
# neg log lik: 1.8965935707092285
# neg log lik: 1.8966692686080933
# neg log lik: 1.8954946994781494
# neg log lik: 1.8952534198760986
# neg log lik: 1.8953858613967896
# neg log lik: 1.8940199613571167
# neg log lik: 1.8941612243652344
# neg log lik: 1.893991231918335
# neg log lik: 1.8930617570877075
# neg log lik: 1.8930150270462036
# neg log lik: 1.8923563957214355
# neg log lik: 1.89225172996521
# neg log lik: 1.891636610031128
# neg log lik: 1.8912830352783203
# neg log lik: 1.8920485973358154
# neg log lik: 1.892451286315918
# neg log lik: 1.8909474611282349
# neg log lik: 1.8898491859436035
# neg log lik: 1.8898996114730835
# neg log lik: 1.889370322227478
# neg log lik: 1.8889662027359009
# neg log lik: 1.890091061592102
# method: taf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.8334381580352783
# neg log lik: 1.8079979419708252
# neg log lik: 1.743962049484253
# neg log lik: 1.7195954322814941
# neg log lik: 1.7099436521530151
# neg log lik: 1.705124855041504
# neg log lik: 1.7021839618682861
# neg log lik: 1.7003799676895142
# neg log lik: 1.6989234685897827
# neg log lik: 1.6978236436843872
# neg log lik: 1.6967750787734985
# neg log lik: 1.69618558883667
# neg log lik: 1.6955609321594238
# neg log lik: 1.695155143737793
# neg log lik: 1.6946204900741577
# neg log lik: 1.693629503250122
# neg log lik: 1.6930005550384521
# neg log lik: 1.6924388408660889
# neg log lik: 1.6918410062789917
# neg log lik: 1.6914080381393433
# neg log lik: 1.6913422346115112
# neg log lik: 1.6906112432479858
# neg log lik: 1.6897692680358887
# neg log lik: 1.688714861869812
# neg log lik: 1.6883254051208496
# neg log lik: 1.687389612197876
# neg log lik: 1.68751859664917
# neg log lik: 1.6863620281219482
# neg log lik: 1.6860042810440063
# neg log lik: 1.685868263244629
# neg log lik: 1.6848702430725098
# neg log lik: 1.68453848361969
# neg log lik: 1.6842097043991089
# neg log lik: 1.6848822832107544
# neg log lik: 1.6847172975540161
# neg log lik: 1.6848959922790527
# neg log lik: 1.6848013401031494
# neg log lik: 1.6839995384216309
# neg log lik: 1.682723879814148
# neg log lik: 1.6828070878982544
# neg log lik: 1.6828187704086304
# neg log lik: 1.6818647384643555
# neg log lik: 1.6843949556350708
# neg log lik: 1.6818045377731323
# neg log lik: 1.6813664436340332
# neg log lik: 1.681320309638977
# neg log lik: 1.6821705102920532
# neg log lik: 1.6805694103240967
# neg log lik: 1.6808363199234009
# neg log lik: 1.6803959608078003
# nu: Parameter containing:
# tensor([-6.9982], requires_grad=True)
# method: ataf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.7738943099975586
# neg log lik: 1.7703055143356323
# neg log lik: 1.7014827728271484
# neg log lik: 1.6633540391921997
# neg log lik: 1.6445205211639404
# neg log lik: 1.635969877243042
# neg log lik: 1.6318280696868896
# neg log lik: 1.629525065422058
# neg log lik: 1.6267060041427612
# neg log lik: 1.6250072717666626
# neg log lik: 1.6235700845718384
# neg log lik: 1.6231399774551392
# neg log lik: 1.6213933229446411
# neg log lik: 1.6206167936325073
# neg log lik: 1.6202269792556763
# neg log lik: 1.619710087776184
# neg log lik: 1.6189900636672974
# neg log lik: 1.6184492111206055
# neg log lik: 1.6179319620132446
# neg log lik: 1.6172420978546143
# neg log lik: 1.6167423725128174
# neg log lik: 1.6162770986557007
# neg log lik: 1.6159592866897583
# neg log lik: 1.615246057510376
# neg log lik: 1.614745855331421
# neg log lik: 1.6145929098129272
# neg log lik: 1.6144176721572876
# neg log lik: 1.6134120225906372
# neg log lik: 1.6129307746887207
# neg log lik: 1.6125553846359253
# neg log lik: 1.612231969833374
# neg log lik: 1.6161385774612427
# neg log lik: 1.6106992959976196
# neg log lik: 1.6154311895370483
# neg log lik: 1.6108366250991821
# neg log lik: 1.6099677085876465
# neg log lik: 1.6099869012832642
# neg log lik: 1.6116209030151367
# neg log lik: 1.610408902168274
# neg log lik: 1.6102476119995117
# neg log lik: 1.6099951267242432
# neg log lik: 1.6094502210617065
# neg log lik: 1.6087225675582886
# neg log lik: 1.6085442304611206
# neg log lik: 1.608123540878296
# neg log lik: 1.6077364683151245
# neg log lik: 1.6072827577590942
# neg log lik: 1.6072628498077393
# neg log lik: 1.6065964698791504
# neg log lik: 1.6064698696136475
# nu: Parameter containing:
# tensor([-8.9321, -7.9574], requires_grad=True)
# method: advi
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.8356049060821533
# neg log lik: 1.977264642715454
# neg log lik: 1.9720317125320435
# neg log lik: 1.9694103002548218
# neg log lik: 1.9668684005737305
# neg log lik: 1.9640507698059082
# neg log lik: 1.9611889123916626
# neg log lik: 1.9584465026855469
# neg log lik: 1.9553645849227905
# neg log lik: 1.952001929283142
# neg log lik: 1.9494227170944214
# neg log lik: 1.9465117454528809
# neg log lik: 1.9377650022506714
# neg log lik: 1.9300037622451782
# neg log lik: 1.9235986471176147
# neg log lik: 1.919273853302002
# neg log lik: 1.9148894548416138
# neg log lik: 1.9121571779251099
# neg log lik: 1.909164547920227
# neg log lik: 1.907143473625183
# neg log lik: 1.9060876369476318
# neg log lik: 1.9046173095703125
# neg log lik: 1.9028677940368652
# neg log lik: 1.902180552482605
# neg log lik: 1.8996707201004028
# neg log lik: 1.8987112045288086
# neg log lik: 1.8974578380584717
# neg log lik: 1.8964817523956299
# neg log lik: 1.8953360319137573
# neg log lik: 1.895398736000061
# neg log lik: 1.893669605255127
# neg log lik: 1.8928911685943604
# neg log lik: 1.8933180570602417
# neg log lik: 1.8930655717849731
# neg log lik: 1.8920576572418213
# neg log lik: 1.8904181718826294
# neg log lik: 1.8897181749343872
# neg log lik: 1.8890645503997803
# neg log lik: 1.8894168138504028
# neg log lik: 1.8880940675735474
# neg log lik: 1.8878363370895386
# neg log lik: 1.887759804725647
# neg log lik: 1.8864537477493286
# neg log lik: 1.8862721920013428
# neg log lik: 1.8857665061950684
# neg log lik: 1.8853918313980103
# neg log lik: 1.8844619989395142
# neg log lik: 1.8871023654937744
# neg log lik: 1.8833911418914795
# neg log lik: 1.8832321166992188
# method: taf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.6386802196502686
# neg log lik: 1.7084451913833618
# neg log lik: 1.6643317937850952
# neg log lik: 1.646514654159546
# neg log lik: 1.63974130153656
# neg log lik: 1.6375278234481812
# neg log lik: 1.6365325450897217
# neg log lik: 1.6356756687164307
# neg log lik: 1.6350469589233398
# neg log lik: 1.6342175006866455
# neg log lik: 1.6332050561904907
# neg log lik: 1.6324936151504517
# neg log lik: 1.6315346956253052
# neg log lik: 1.630126714706421
# neg log lik: 1.6292284727096558
# neg log lik: 1.6283140182495117
# neg log lik: 1.6275893449783325
# neg log lik: 1.6271353960037231
# neg log lik: 1.6261537075042725
# neg log lik: 1.62713623046875
# neg log lik: 1.623901605606079
# neg log lik: 1.6237819194793701
# neg log lik: 1.622487187385559
# neg log lik: 1.621307611465454
# neg log lik: 1.6205805540084839
# neg log lik: 1.6196691989898682
# neg log lik: 1.619543433189392
# neg log lik: 1.6190285682678223
# neg log lik: 1.6178916692733765
# neg log lik: 1.617066740989685
# neg log lik: 1.6161259412765503
# neg log lik: 1.6153652667999268
# neg log lik: 1.6147427558898926
# neg log lik: 1.6142719984054565
# neg log lik: 1.613835334777832
# neg log lik: 1.6134251356124878
# neg log lik: 1.6129721403121948
# neg log lik: 1.6126132011413574
# neg log lik: 1.6133427619934082
# neg log lik: 1.6125049591064453
# neg log lik: 1.6116114854812622
# neg log lik: 1.6121807098388672
# neg log lik: 1.611253261566162
# neg log lik: 1.705839991569519
# neg log lik: 1.6137150526046753
# neg log lik: 1.6131906509399414
# neg log lik: 1.6127991676330566
# neg log lik: 1.6124869585037231
# neg log lik: 1.6121118068695068
# neg log lik: 1.6118417978286743
# nu: Parameter containing:
# tensor([-9.0262], requires_grad=True)
# method: ataf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.6978089809417725
# neg log lik: 1.6958110332489014
# neg log lik: 1.6574615240097046
# neg log lik: 1.6433546543121338
# neg log lik: 1.6385436058044434
# neg log lik: 1.6364151239395142
# neg log lik: 1.6342415809631348
# neg log lik: 1.6321699619293213
# neg log lik: 1.630288004875183
# neg log lik: 1.6294351816177368
# neg log lik: 1.627905011177063
# neg log lik: 1.6266462802886963
# neg log lik: 1.623915433883667
# neg log lik: 1.6224595308303833
# neg log lik: 1.620049238204956
# neg log lik: 1.6195414066314697
# neg log lik: 1.6180553436279297
# neg log lik: 1.6174870729446411
# neg log lik: 1.6179237365722656
# neg log lik: 1.6153900623321533
# neg log lik: 1.6144087314605713
# neg log lik: 1.613620400428772
# neg log lik: 1.6138298511505127
# neg log lik: 1.6118046045303345
# neg log lik: 1.6114351749420166
# neg log lik: 1.6117902994155884
# neg log lik: 1.610967755317688
# neg log lik: 1.608636736869812
# neg log lik: 1.6087281703948975
# neg log lik: 1.6076463460922241
# neg log lik: 1.6068249940872192
# neg log lik: 1.6057367324829102
# neg log lik: 1.605355143547058
# neg log lik: 1.6054617166519165
# neg log lik: 1.6046963930130005
# neg log lik: 1.6043778657913208
# neg log lik: 1.6043477058410645
# neg log lik: 1.6036287546157837
# neg log lik: 1.6033748388290405
# neg log lik: 1.6027226448059082
# neg log lik: 1.6028668880462646
# neg log lik: 1.6023170948028564
# neg log lik: 1.6021711826324463
# neg log lik: 1.60164213180542
# neg log lik: 1.601506233215332
# neg log lik: 1.6011773347854614
# neg log lik: 1.6014066934585571
# neg log lik: 1.6008268594741821
# neg log lik: 1.6002503633499146
# neg log lik: 1.6002711057662964
# nu: Parameter containing:
# tensor([-9.1687, -7.6834], requires_grad=True)
# method: advi
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.973705768585205
# neg log lik: 1.9066333770751953
# neg log lik: 1.9012635946273804
# neg log lik: 1.8967397212982178
# neg log lik: 1.894466519355774
# neg log lik: 1.8937071561813354
# neg log lik: 1.8932844400405884
# neg log lik: 1.8928889036178589
# neg log lik: 1.8924938440322876
# neg log lik: 1.8921512365341187
# neg log lik: 1.8918347358703613
# neg log lik: 1.8915349245071411
# neg log lik: 1.8911821842193604
# neg log lik: 1.890869379043579
# neg log lik: 1.8905067443847656
# neg log lik: 1.890120267868042
# neg log lik: 1.8897387981414795
# neg log lik: 1.8892264366149902
# neg log lik: 1.888720989227295
# neg log lik: 1.8881261348724365
# neg log lik: 1.8874833583831787
# neg log lik: 1.8867427110671997
# neg log lik: 1.8860336542129517
# neg log lik: 1.8853131532669067
# neg log lik: 1.8845648765563965
# neg log lik: 1.8837478160858154
# neg log lik: 1.8831615447998047
# neg log lik: 1.8817411661148071
# neg log lik: 1.8807209730148315
# neg log lik: 1.8798611164093018
# neg log lik: 1.8791524171829224
# neg log lik: 1.8784377574920654
# neg log lik: 1.8779270648956299
# neg log lik: 1.877394437789917
# neg log lik: 1.8768748044967651
# neg log lik: 1.875617265701294
# neg log lik: 1.874979853630066
# neg log lik: 1.8741291761398315
# neg log lik: 1.8731745481491089
# neg log lik: 1.8720475435256958
# neg log lik: 1.8714416027069092
# neg log lik: 1.870977759361267
# neg log lik: 1.8705425262451172
# neg log lik: 1.869579553604126
# neg log lik: 1.8687855005264282
# neg log lik: 1.8684601783752441
# neg log lik: 1.867446780204773
# neg log lik: 1.867347240447998
# neg log lik: 1.8671596050262451
# neg log lik: 1.866422176361084
# method: taf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.735780715942383
# neg log lik: 1.731326699256897
# neg log lik: 1.677033543586731
# neg log lik: 1.6516004800796509
# neg log lik: 1.640934944152832
# neg log lik: 1.636793851852417
# neg log lik: 1.6345560550689697
# neg log lik: 1.6328850984573364
# neg log lik: 1.6306614875793457
# neg log lik: 1.629319667816162
# neg log lik: 1.627844214439392
# neg log lik: 1.626641035079956
# neg log lik: 1.625472903251648
# neg log lik: 1.6241477727890015
# neg log lik: 1.6234017610549927
# neg log lik: 1.621699571609497
# neg log lik: 1.6210498809814453
# neg log lik: 1.6207941770553589
# neg log lik: 1.620136022567749
# neg log lik: 1.619820237159729
# neg log lik: 1.6191351413726807
# neg log lik: 1.6187454462051392
# neg log lik: 1.618486762046814
# neg log lik: 1.6177647113800049
# neg log lik: 1.6177157163619995
# neg log lik: 1.6169238090515137
# neg log lik: 1.6167958974838257
# neg log lik: 1.6152427196502686
# neg log lik: 1.616122841835022
# neg log lik: 1.6152839660644531
# neg log lik: 1.6159535646438599
# neg log lik: 1.6143035888671875
# neg log lik: 1.6140774488449097
# neg log lik: 1.6142463684082031
# neg log lik: 1.6139222383499146
# neg log lik: 1.6134042739868164
# neg log lik: 1.613109827041626
# neg log lik: 1.612873911857605
# neg log lik: 1.612306833267212
# neg log lik: 1.6130033731460571
# neg log lik: 1.6131365299224854
# neg log lik: 1.612636685371399
# neg log lik: 1.612013578414917
# neg log lik: 1.6119812726974487
# neg log lik: 1.6119542121887207
# neg log lik: 1.6113905906677246
# neg log lik: 1.6112375259399414
# neg log lik: 1.6110668182373047
# neg log lik: 1.6107510328292847
# neg log lik: 1.6104904413223267
# nu: Parameter containing:
# tensor([-9.0319], requires_grad=True)
# method: ataf
#   0%|          | 0/5000 [00:00<?, ?it/s]
# neg log lik: 2.7233998775482178
# neg log lik: 1.7163114547729492
# neg log lik: 1.667150616645813
# neg log lik: 1.646750807762146
# neg log lik: 1.63835871219635
# neg log lik: 1.634812831878662
# neg log lik: 1.6334120035171509
# neg log lik: 1.6319938898086548
# neg log lik: 1.6307653188705444
# neg log lik: 1.6292226314544678
# neg log lik: 1.6275458335876465
# neg log lik: 1.6259983777999878
# neg log lik: 1.6249393224716187
# neg log lik: 1.6231907606124878
# neg log lik: 1.6222624778747559
# neg log lik: 1.6207562685012817
# neg log lik: 1.6196296215057373
# neg log lik: 1.6186624765396118
# neg log lik: 1.6177661418914795
# neg log lik: 1.616958498954773
# neg log lik: 1.615285873413086
# neg log lik: 1.6140975952148438
# neg log lik: 1.6136289834976196
# neg log lik: 1.6122428178787231
# neg log lik: 1.6118788719177246
# neg log lik: 1.6104308366775513
# neg log lik: 1.6094815731048584
# neg log lik: 1.6088086366653442
# neg log lik: 1.6081268787384033
# neg log lik: 1.607319951057434
# neg log lik: 1.6098387241363525
# neg log lik: 1.6075445413589478
# neg log lik: 1.606616735458374
# neg log lik: 1.6049995422363281
# neg log lik: 1.6046921014785767
# neg log lik: 1.6040804386138916
# neg log lik: 1.6029170751571655
# neg log lik: 1.6023176908493042
# neg log lik: 1.601740837097168
# neg log lik: 1.6012064218521118
# neg log lik: 1.6006771326065063
# neg log lik: 1.600424885749817
# neg log lik: 1.6004940271377563
# neg log lik: 1.5988129377365112
# neg log lik: 1.599703311920166
# neg log lik: 1.5984785556793213
# neg log lik: 1.597148060798645
# neg log lik: 1.5972405672073364
# neg log lik: 1.5961310863494873
# neg log lik: 1.5962235927581787
# nu: Parameter containing:
# tensor([-9.1638, -7.6159], requires_grad=True)

# %%
df_loss = pd.concat((pd.DataFrame({
    'loss': all_losses[trial][name],
    'iter': range(1,len(all_losses[trial][name])+1),
    'method': name,
    'trial': trial,
}) for trial in range(len(all_losses)) for name in all_losses[trial]), ignore_index=True)


import pickle
pickle.dump(df_loss, open('df_loss_insurance.pkl', 'wb'))
#df_loss = pickle.load(open('df_loss_insurance.pkl', 'rb'))

#df_loss['log likelihood'] = -df_loss['loss']
g = sns.relplot(data=df_loss, kind='line', x='iter', y='loss', hue='method')
g.set(yscale='log', xlim=(0,None), ylim=(None, 2))

# %%
df_loss[df_loss['iter'] == df_loss['iter'].max()].groupby('method').describe()
# Out:
#         loss                                                              \
#        count      mean       std       min       25%       50%       75%
# method
# advi    10.0  1.882847  0.012179  1.863474  1.875577  1.885937  1.890036
# ataf    10.0  1.602540  0.004624  1.596224  1.600550  1.602055  1.604207
# taf     10.0  1.658986  0.034240  1.606519  1.627442  1.677909  1.680995
#
#                   iter        ...             trial                           \
#              max count  mean  ...   75%   max count mean      std  min   25%
# method                        ...
# advi    1.902939  10.0  50.0  ...  50.0  50.0  10.0  4.5  3.02765  0.0  2.25
# ataf    1.612397  10.0  50.0  ...  50.0  50.0  10.0  4.5  3.02765  0.0  2.25
# taf     1.684966  10.0  50.0  ...  50.0  50.0  10.0  4.5  3.02765  0.0  2.25
#
#
#         50%   75%  max
# method
# advi    4.5  6.75  9.0
# ataf    4.5  6.75  9.0
# taf     4.5  6.75  9.0
#
# [3 rows x 24 columns]

# %%
sns.displot(
    data=df_loss[df_loss['iter'] == df_loss['iter'].max()],
    hue='method',
    x='loss',
    kind='kde',
)

# %%
samples = all_samples[-1]
df = df_claims.copy()
df['method'] = 'p'
dfs = [df]
for name in samples:
    df = pd.DataFrame(samples[name].numpy(), columns=df_claims.columns)
    df['method'] = name
    dfs.append(df)
df_samples = pd.concat(dfs, ignore_index=True)

import pickle
#pickle.dump(df_samples, open('df_samples_insurance.pkl', 'wb'))
#df_samples = pickle.load(open('df_samples_insurance.pkl', 'rb'))

sns.displot(
    data=df_samples,
    x='log_total_inpatient',
    y='log_total_outpatient',
    hue='method',
)

# %%
g = sns.displot(
    data=df_samples.melt(id_vars=["method"]),
    x='value', 
    hue="method", 
    kind='hist',
    col='variable',
)
g.set(xscale='linear', yscale='linear', ylim=(1e-8,None), xlim=(-5,5))

# %%
g = sns.displot(
    data=df_samples.melt(id_vars=["method"]),
    x='value', 
    hue="method", 
    kind='ecdf',
    col='variable',
)
g.set(xscale='linear', yscale='linear', ylim=(1e-8,None), xlim=(-5,5))
